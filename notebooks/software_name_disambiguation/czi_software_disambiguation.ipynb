# %% [markdown]
# # Software Disambiguation
#
# In this notebook, we shall disambiguate some of the software mentions in the CZI old dataset. We shall do so by simply using the fuzzy matching.

# %%
# Importing the relevant libraries
import pandas as pd
from thefuzz import fuzz
from thefuzz import process

# %%
# Now let us load the old dataset
ROOT_DIR = 'old/'
df_czi_old = pd.read_csv(ROOT_DIR+"/disambiguated/comm_disambiguated.tsv.gz", compression='gzip', sep='\t')
df_czi_old.head(1)
# Out:
#   license                      location    pmcid  pmid  \
# 0    comm  comm/Micropl/PMC8475362.nxml  8475362   NaN
#
#                           doi  pubdate  \
# 0  10.1186/s43591-021-00017-9     2021
#
#                                               source  number  \
# 0  Particle selection and identification of polym...       7
#
#                                                 text          software  \
# 0  Then, all items were photographed under a bino...  Olympus CellSens
#
#   version   ID curation_label mapped_to_software
# 0     NaN  SM0    not_curated   Olympus cellSens

# %%
# Let us get the list of all softwares so we can do fuzzy matching on those
lst_software = df_czi_old[df_czi_old.curation_label.eq('software')].sort_values(by='mapped_to_software')\
        .drop_duplicates(subset='mapped_to_software').mapped_to_software.tolist()

# %%
# Number of unique softwares within the old dataset
print("Number of unique softwares within the old dataset", len(lst_software))
# Out:
# Number of unique softwares within the old dataset 4639

# %%
# Identifying the software mapping so we can standardize the software names
s2s = {} # initializing a mapping dictionary

# Goign through each software and identifying the closest software based on fuzzy matching
for software in lst_software:
    # We shall only extract the top choice
    choice = process.extract(software, lst_software, limit=1)
    # We will only consider choices if they are not the same name
    if(software != choice[0][0]):
        # Add it to the dictionary
        print(software, choice)
        s2s[software] = choice

s2s
# Out:
# 3-matic [('3-Matic', 100)]
# 3D-Slicer [('3D Slicer', 100)]
# ANSYS Fluent [('ANSYS FLUENT', 100)]
# ANTs [('ANTS', 100)]
# ASReml [('ASREML', 100)]
# Abaqus [('ABAQUS', 100)]
# Actilife [('ActiLife', 100)]
# Adaboost [('AdaBoost', 100)]
# Adonis [('ADONIS', 100)]
# Amos [('AMOS', 100)]
# Anaconda [('ANACONDA', 100)]
# Ansys [('ANSYS', 100)]
# ArcGIS [('ARCGIS', 100)]
# ArcGis [('ARCGIS', 100)]
# Arcgis [('ARCGIS', 100)]
# Atlas.ti [('ATLAS.ti', 100)]
# Avizo [('AVIZO', 100)]
# BEAUti [('BEAUTi', 100)]
# BWA mem [('BWA MEM', 100)]
# BWA-MEM [('BWA MEM', 100)]
# BWA-mem [('BWA MEM', 100)]
# BayeScan [('BAYESCAN', 100)]
# BayesAss [('BAYESASS', 100)]
# Bayescan [('BAYESCAN', 100)]
# Beagle [('BEAGLE', 100)]
# BiNGO [('BINGO', 100)]
# BinGO [('BINGO', 100)]
# Bingo [('BINGO', 100)]
# BioNJ [('BIONJ', 100)]
# Bioclim [('BIOCLIM', 100)]
# Bioperl [('BioPerl', 100)]
# Biotools [('BioTools', 100)]
# Biotyper [('BioTyper', 100)]
# BootScan [('BOOTSCAN', 100)]
# Bootscan [('BOOTSCAN', 100)]
# Bottleneck [('BOTTLENECK', 100)]
# CD-search [('CD-Search', 100)]
# CELLQuest [('CELLQUEST', 100)]
# CTan [('CTAn', 100)]
# CTvox [('CTVox', 100)]
# Calm [('CALM', 100)]
# Canoco [('CANOCO', 100)]
# Cap3 [('CAP3', 100)]
# Capture [('CAPTURE', 100)]
# CellQuest [('CELLQUEST', 100)]
# Cervus [('CERVUS', 100)]
# ChAMP [('CHAMP', 100)]
# Chart [('CHART', 100)]
# ChromoPainter [('CHROMOPAINTER', 100)]
# CodeML [('CODEML', 100)]
# Combat [('ComBat', 100)]
# Comsol [('COMSOL', 100)]
# Consurf [('ConSurf', 100)]
# CorelDraw [('CorelDRAW', 100)]
# Cutadapt [('CutAdapt', 100)]
# DNAman [('DNAMAN', 100)]
# Darwin [('DARwin', 100)]
# Deeplab [('DeepLab', 100)]
# Dialign [('DIALIGN', 100)]
# DichroWeb [('DICHROWEB', 100)]
# Distruct [('DISTRUCT', 100)]
# Diva [('DIVA', 100)]
# Dragon [('DRAGON', 100)]
# EEGlab [('EEGLAB', 100)]
# ESTscan [('ESTScan', 100)]
# Easyfig [('EasyFig', 100)]
# EchoPac [('EchoPAC', 100)]
# Epi [('EPI', 100)]
# Epi data [('Epi Data', 100)]
# Epi-data [('Epi Data', 100)]
# Epic [('EPIC', 100)]
# Epidat [('EPIDAT', 100)]
# Epidata [('EpiData', 100)]
# Esri ArcGIS [('ESRI ArcGIS', 100)]
# Evolview [('EvolView', 100)]
# Excel [('EXCEL', 100)]
# Expander [('EXPANDER', 100)]
# Fgenesh [('FGENESH', 100)]
# Fiji [('FiJi', 100)]
# Fiji ImageJ [('FIJI/ImageJ', 100)]
# Fragstats [('FRAGSTATS', 100)]
# Fstat [('FSTAT', 100)]
# G-Power [('G*Power', 100)]
# G-power [('G*Power', 100)]
# Garli [('GARLI', 100)]
# Gblocks [('GBLOCKS', 100)]
# Gbrowse [('GBrowse', 100)]
# Geant4 [('GEANT4', 100)]
# GeneMapper [('GENEMAPPER', 100)]
# GeneScan [('GENESCAN', 100)]
# Geneconv [('GENECONV', 100)]
# Geneland [('GENELAND', 100)]
# Genepix [('GenePix', 100)]
# Genetix [('GENETIX', 100)]
# Genetyx [('GENETYX', 100)]
# GenoDive [('GENODIVE', 100)]
# Gimp [('GIMP', 100)]
# GoogleNet [('GoogLeNet', 100)]
# Gorilla [('GOrilla', 100)]
# Gpower [('GPower', 100)]
# Grafit [('GraFit', 100)]
# Graphviz [('GraphViz', 100)]
# G∗Power [('G*Power', 100)]
# HHblits [('HHBlits', 100)]
# HHsearch [('HHSearch', 100)]
# HMMer [('HMMER', 100)]
# Haddock [('HADDOCK', 100)]
# Haploview [('HAPLOVIEW', 100)]
# Hex [('HEX', 100)]
# Hotnet2 [('HotNet2', 100)]
# HyPhy [('HYPHY', 100)]
# IQ-Tree [('IQ-TREE', 100)]
# IQTree [('IQTREE', 100)]
# IQtree [('IQTREE', 100)]
# Igor [('IGOR', 100)]
# Imagene [('ImaGene', 100)]
# Image‐Pro Plus [('Image-Pro Plus', 100)]
# Impute2 [('IMPUTE2', 100)]
# Infomap [('InfoMap', 100)]
# Inparanoid [('InParanoid', 100)]
# Instat [('InStat', 100)]
# Isomap [('ISOMAP', 100)]
# Java [('JAVA', 100)]
# KM-plotter [('KM plotter', 100)]
# LAS-AF [('LAS AF', 100)]
# Labchart [('LabChart', 100)]
# Labworks [('LabWorks', 100)]
# Lisrel [('LISREL', 100)]
# MCMCtree [('MCMCTree', 100)]
# MClust [('MCLUST', 100)]
# MEGA-X [('MEGA X', 100)]
# MFold [('MFOLD', 100)]
# MS-Excel [('MS Excel', 100)]
# Manta [('MANTA', 100)]
# MapMaker [('MAPMAKER', 100)]
# Mapmaker [('MAPMAKER', 100)]
# Mapman [('MapMan', 100)]
# Marsbar [('MarsBaR', 100)]
# Matlab script [('MATLAB script', 100)]
# Matlab/Simulink [('MATLAB/Simulink', 100)]
# Maven [('MAVEN', 100)]
# MaxEnt [('MAXENT', 100)]
# MaxQDA [('MAXQDA', 100)]
# MeV [('MEV', 100)]
# Medusa [('MEDUSA', 100)]
# Mega [('MEGA', 100)]
# Megalign [('MegAlign', 100)]
# Meshlab [('MeshLab', 100)]
# Mesquite [('MESQUITE', 100)]
# Metscape [('MetScape', 100)]
# Mev [('MEV', 100)]
# Mfold [('MFOLD', 100)]
# MiST [('MIST', 100)]
# Micro-Checker [('MICRO-CHECKER', 100)]
# Migrate [('MIGRATE', 100)]
# Modeltest [('MODELTEST', 100)]
# Modfit [('ModFit', 100)]
# Molrep [('MOLREP', 100)]
# Mrbayes [('MrBayes', 100)]
# Multalin [('MultAlin', 100)]
# Multiz [('MULTIZ', 100)]
# Mummer [('MUMmer', 100)]
# NNSplice [('NNSPLICE', 100)]
# Network [('NETWORK', 100)]
# NewHybrids [('NEWHYBRIDS', 100)]
# Nucmer [('NUCmer', 100)]
# Octopus [('OCTOPUS', 100)]
# Olex2 [('OLEX2', 100)]
# Omnic [('OMNIC', 100)]
# PSI-Blast [('PSI-BLAST', 100)]
# Perl [('PERL', 100)]
# Perl script [('PERL script', 100)]
# Phase [('PHASE', 100)]
# Phyml [('PhyML', 100)]
# PopArt [('PopART', 100)]
# Praat [('PRAAT', 100)]
# ProSA [('PROSA', 100)]
# Probcons [('ProbCons', 100)]
# Proteus [('PROTEUS', 100)]
# Provean [('PROVEAN', 100)]
# Psipred [('PSIPRED', 100)]
# QGis [('QGIS', 100)]
# Quanto [('QUANTO', 100)]
# R commander [('R Commander', 100)]
# R studio [('R Studio', 100)]
# R-Studio [('R Studio', 100)]
# R-script [('R script', 100)]
# R-studio [('R Studio', 100)]
# RNAfold [('RNAFold', 100)]
# RNAhybrid [('RNAHybrid', 100)]
# Rasmol [('RasMol', 100)]
# Refseq [('RefSeq', 100)]
# Resfinder [('ResFinder', 100)]
# S-Plus [('S-PLUS', 100)]
# SPSS Amos [('SPSS AMOS', 100)]
# SatScan [('SaTScan', 100)]
# Scala [('SCALA', 100)]
# Search [('SEARCH', 100)]
# Sedfit [('SEDFIT', 100)]
# Seqman [('SeqMan', 100)]
# Sequest [('SEQUEST', 100)]
# SiScan [('SISCAN', 100)]
# Sift [('SIFT', 100)]
# Simca-P [('SIMCA-P', 100)]
# Simplot [('SimPlot', 100)]
# Sirius [('SIRIUS', 100)]
# Skyscan [('SkyScan', 100)]
# Softworx [('SoftWoRx', 100)]
# Stata/IC [('STATA/IC', 100)]
# Stata/MP [('STATA/MP', 100)]
# Stata/SE [('STATA/SE', 100)]
# Structure [('STRUCTURE', 100)]
# Sybyl [('SYBYL', 100)]
# Sybyl-X [('SYBYL-X', 100)]
# TRaCE [('TRACE', 100)]
# Tandem [('TANDEM', 100)]
# Tassel [('TASSEL', 100)]
# TomTom [('TOMTOM', 100)]
# Tomtec [('TomTec', 100)]
# Tomtom [('TOMTOM', 100)]
# Topas [('TOPAS', 100)]
# Tracer [('TRACER', 100)]
# Tree-Puzzle [('TREE-PUZZLE', 100)]
# TreeMix [('TREEMIX', 100)]
# Treefinder [('TreeFinder', 100)]
# Turbomole [('TURBOMOLE', 100)]
# Uclust [('UCLUST', 100)]
# Unet [('UNet', 100)]
# Usearch [('USEARCH', 100)]
# Venny [('VENNY', 100)]
# Verify3D [('VERIFY3D', 100)]
# Vicon [('VICON', 100)]
# WinPepi [('WINPEPI', 100)]
# Winsteps [('WINSTEPS', 100)]
# Xcalibur [('XCalibur', 100)]
# Xplor-NIH [('XPLOR-NIH', 100)]
# Zemax [('ZEMAX', 100)]
# Zen [('ZEN', 100)]
# adonis [('ADONIS', 100)]
# ape [('APE', 100)]
# bcftools [('BCFtools', 100)]
# bismark [('Bismark', 100)]
# bwa mem [('BWA MEM', 100)]
# bwa-mem [('BWA MEM', 100)]
# car [('CAR', 100)]
# caret [('Caret', 100)]
# cd-hit-est [('CD-HIT-EST', 100)]
# cpptraj [('CPPTRAJ', 100)]
# eXpress [('Express', 100)]
# fastStructure [('fastSTRUCTURE', 100)]
# fastx [('FASTX', 100)]
# gamlss [('GAMLSS', 100)]
# gcc [('GCC', 100)]
# gcrma [('GCRMA', 100)]
# glm [('GLM', 100)]
# glmnet [('Glmnet', 100)]
# heatmap [('HeatMap', 100)]
# hmmsearch [('HMMsearch', 100)]
# inForm [('InForm', 100)]
# jModelTest [('JMODELTEST', 100)]
# keras [('Keras', 100)]
# lavaan [('Lavaan', 100)]
# mFold [('MFOLD', 100)]
# maps [('MAPS', 100)]
# mclust [('MCLUST', 100)]
# mega [('MEGA', 100)]
# mfold [('MFOLD', 100)]
# mice [('MICE', 100)]
# msconvert [('MSConvert', 100)]
# mySQL [('MySQL', 100)]
# nucmer [('NUCmer', 100)]
# pLink [('PLINK', 100)]
# perl [('PERL', 100)]
# phrap [('Phrap', 100)]
# pls [('PLS', 100)]
# psi-blast [('PSI-BLAST', 100)]
# pythia [('Pythia', 100)]
# rstan [('RStan', 100)]
# sPLS [('SPLS', 100)]
# samtools mpileup [('SAMtools mpileup', 100)]
# scanpy [('Scanpy', 100)]
# shiny [('Shiny', 100)]
# smartpca [('SMARTPCA', 100)]
# tBLASTx [('TBLASTX', 100)]
# tBlastn [('TBLASTN', 100)]
# tblastx [('TBLASTX', 100)]
# uclust [('UCLUST', 100)]
# viewer [('Viewer', 100)]
# vsearch [('VSEARCH', 100)]
# {'3-matic': [('3-Matic', 100)],
#  '3D-Slicer': [('3D Slicer', 100)],
#  'ANSYS Fluent': [('ANSYS FLUENT', 100)],
#  'ANTs': [('ANTS', 100)],
#  'ASReml': [('ASREML', 100)],
#  'Abaqus': [('ABAQUS', 100)],
#  'Actilife': [('ActiLife', 100)],
#  'Adaboost': [('AdaBoost', 100)],
#  'Adonis': [('ADONIS', 100)],
#  'Amos': [('AMOS', 100)],
#  'Anaconda': [('ANACONDA', 100)],
#  'Ansys': [('ANSYS', 100)],
#  'ArcGIS': [('ARCGIS', 100)],
#  'ArcGis': [('ARCGIS', 100)],
#  'Arcgis': [('ARCGIS', 100)],
#  'Atlas.ti': [('ATLAS.ti', 100)],
#  'Avizo': [('AVIZO', 100)],
#  'BEAUti': [('BEAUTi', 100)],
#  'BWA mem': [('BWA MEM', 100)],
#  'BWA-MEM': [('BWA MEM', 100)],
#  'BWA-mem': [('BWA MEM', 100)],
#  'BayeScan': [('BAYESCAN', 100)],
#  'BayesAss': [('BAYESASS', 100)],
#  'Bayescan': [('BAYESCAN', 100)],
#  'Beagle': [('BEAGLE', 100)],
#  'BiNGO': [('BINGO', 100)],
#  'BinGO': [('BINGO', 100)],
#  'Bingo': [('BINGO', 100)],
#  'BioNJ': [('BIONJ', 100)],
#  'Bioclim': [('BIOCLIM', 100)],
#  'Bioperl': [('BioPerl', 100)],
#  'Biotools': [('BioTools', 100)],
#  'Biotyper': [('BioTyper', 100)],
#  'BootScan': [('BOOTSCAN', 100)],
#  'Bootscan': [('BOOTSCAN', 100)],
#  'Bottleneck': [('BOTTLENECK', 100)],
#  'CD-search': [('CD-Search', 100)],
#  'CELLQuest': [('CELLQUEST', 100)],
#  'CTan': [('CTAn', 100)],
#  'CTvox': [('CTVox', 100)],
#  'Calm': [('CALM', 100)],
#  'Canoco': [('CANOCO', 100)],
#  'Cap3': [('CAP3', 100)],
#  'Capture': [('CAPTURE', 100)],
#  'CellQuest': [('CELLQUEST', 100)],
#  'Cervus': [('CERVUS', 100)],
#  'ChAMP': [('CHAMP', 100)],
#  'Chart': [('CHART', 100)],
#  'ChromoPainter': [('CHROMOPAINTER', 100)],
#  'CodeML': [('CODEML', 100)],
#  'Combat': [('ComBat', 100)],
#  'Comsol': [('COMSOL', 100)],
#  'Consurf': [('ConSurf', 100)],
#  'CorelDraw': [('CorelDRAW', 100)],
#  'Cutadapt': [('CutAdapt', 100)],
#  'DNAman': [('DNAMAN', 100)],
#  'Darwin': [('DARwin', 100)],
#  'Deeplab': [('DeepLab', 100)],
#  'Dialign': [('DIALIGN', 100)],
#  'DichroWeb': [('DICHROWEB', 100)],
#  'Distruct': [('DISTRUCT', 100)],
#  'Diva': [('DIVA', 100)],
#  'Dragon': [('DRAGON', 100)],
#  'EEGlab': [('EEGLAB', 100)],
#  'ESTscan': [('ESTScan', 100)],
#  'Easyfig': [('EasyFig', 100)],
#  'EchoPac': [('EchoPAC', 100)],
#  'Epi': [('EPI', 100)],
#  'Epi data': [('Epi Data', 100)],
#  'Epi-data': [('Epi Data', 100)],
#  'Epic': [('EPIC', 100)],
#  'Epidat': [('EPIDAT', 100)],
#  'Epidata': [('EpiData', 100)],
#  'Esri ArcGIS': [('ESRI ArcGIS', 100)],
#  'Evolview': [('EvolView', 100)],
#  'Excel': [('EXCEL', 100)],
#  'Expander': [('EXPANDER', 100)],
#  'Fgenesh': [('FGENESH', 100)],
#  'Fiji': [('FiJi', 100)],
#  'Fiji ImageJ': [('FIJI/ImageJ', 100)],
#  'Fragstats': [('FRAGSTATS', 100)],
#  'Fstat': [('FSTAT', 100)],
#  'G-Power': [('G*Power', 100)],
#  'G-power': [('G*Power', 100)],
#  'Garli': [('GARLI', 100)],
#  'Gblocks': [('GBLOCKS', 100)],
#  'Gbrowse': [('GBrowse', 100)],
#  'Geant4': [('GEANT4', 100)],
#  'GeneMapper': [('GENEMAPPER', 100)],
#  'GeneScan': [('GENESCAN', 100)],
#  'Geneconv': [('GENECONV', 100)],
#  'Geneland': [('GENELAND', 100)],
#  'Genepix': [('GenePix', 100)],
#  'Genetix': [('GENETIX', 100)],
#  'Genetyx': [('GENETYX', 100)],
#  'GenoDive': [('GENODIVE', 100)],
#  'Gimp': [('GIMP', 100)],
#  'GoogleNet': [('GoogLeNet', 100)],
#  'Gorilla': [('GOrilla', 100)],
#  'Gpower': [('GPower', 100)],
#  'Grafit': [('GraFit', 100)],
#  'Graphviz': [('GraphViz', 100)],
#  'G∗Power': [('G*Power', 100)],
#  'HHblits': [('HHBlits', 100)],
#  'HHsearch': [('HHSearch', 100)],
#  'HMMer': [('HMMER', 100)],
#  'Haddock': [('HADDOCK', 100)],
#  'Haploview': [('HAPLOVIEW', 100)],
#  'Hex': [('HEX', 100)],
#  'Hotnet2': [('HotNet2', 100)],
#  'HyPhy': [('HYPHY', 100)],
#  'IQ-Tree': [('IQ-TREE', 100)],
#  'IQTree': [('IQTREE', 100)],
#  'IQtree': [('IQTREE', 100)],
#  'Igor': [('IGOR', 100)],
#  'Imagene': [('ImaGene', 100)],
#  'Image‐Pro Plus': [('Image-Pro Plus', 100)],
#  'Impute2': [('IMPUTE2', 100)],
#  'Infomap': [('InfoMap', 100)],
#  'Inparanoid': [('InParanoid', 100)],
#  'Instat': [('InStat', 100)],
#  'Isomap': [('ISOMAP', 100)],
#  'Java': [('JAVA', 100)],
#  'KM-plotter': [('KM plotter', 100)],
#  'LAS-AF': [('LAS AF', 100)],
#  'Labchart': [('LabChart', 100)],
#  'Labworks': [('LabWorks', 100)],
#  'Lisrel': [('LISREL', 100)],
#  'MCMCtree': [('MCMCTree', 100)],
#  'MClust': [('MCLUST', 100)],
#  'MEGA-X': [('MEGA X', 100)],
#  'MFold': [('MFOLD', 100)],
#  'MS-Excel': [('MS Excel', 100)],
#  'Manta': [('MANTA', 100)],
#  'MapMaker': [('MAPMAKER', 100)],
#  'Mapmaker': [('MAPMAKER', 100)],
#  'Mapman': [('MapMan', 100)],
#  'Marsbar': [('MarsBaR', 100)],
#  'Matlab script': [('MATLAB script', 100)],
#  'Matlab/Simulink': [('MATLAB/Simulink', 100)],
#  'Maven': [('MAVEN', 100)],
#  'MaxEnt': [('MAXENT', 100)],
#  'MaxQDA': [('MAXQDA', 100)],
#  'MeV': [('MEV', 100)],
#  'Medusa': [('MEDUSA', 100)],
#  'Mega': [('MEGA', 100)],
#  'Megalign': [('MegAlign', 100)],
#  'Meshlab': [('MeshLab', 100)],
#  'Mesquite': [('MESQUITE', 100)],
#  'Metscape': [('MetScape', 100)],
#  'Mev': [('MEV', 100)],
#  'Mfold': [('MFOLD', 100)],
#  'MiST': [('MIST', 100)],
#  'Micro-Checker': [('MICRO-CHECKER', 100)],
#  'Migrate': [('MIGRATE', 100)],
#  'Modeltest': [('MODELTEST', 100)],
#  'Modfit': [('ModFit', 100)],
#  'Molrep': [('MOLREP', 100)],
#  'Mrbayes': [('MrBayes', 100)],
#  'Multalin': [('MultAlin', 100)],
#  'Multiz': [('MULTIZ', 100)],
#  'Mummer': [('MUMmer', 100)],
#  'NNSplice': [('NNSPLICE', 100)],
#  'Network': [('NETWORK', 100)],
#  'NewHybrids': [('NEWHYBRIDS', 100)],
#  'Nucmer': [('NUCmer', 100)],
#  'Octopus': [('OCTOPUS', 100)],
#  'Olex2': [('OLEX2', 100)],
#  'Omnic': [('OMNIC', 100)],
#  'PSI-Blast': [('PSI-BLAST', 100)],
#  'Perl': [('PERL', 100)],
#  'Perl script': [('PERL script', 100)],
#  'Phase': [('PHASE', 100)],
#  'Phyml': [('PhyML', 100)],
#  'PopArt': [('PopART', 100)],
#  'Praat': [('PRAAT', 100)],
#  'ProSA': [('PROSA', 100)],
#  'Probcons': [('ProbCons', 100)],
#  'Proteus': [('PROTEUS', 100)],
#  'Provean': [('PROVEAN', 100)],
#  'Psipred': [('PSIPRED', 100)],
#  'QGis': [('QGIS', 100)],
#  'Quanto': [('QUANTO', 100)],
#  'R commander': [('R Commander', 100)],
#  'R studio': [('R Studio', 100)],
#  'R-Studio': [('R Studio', 100)],
#  'R-script': [('R script', 100)],
#  'R-studio': [('R Studio', 100)],
#  'RNAfold': [('RNAFold', 100)],
#  'RNAhybrid': [('RNAHybrid', 100)],
#  'Rasmol': [('RasMol', 100)],
#  'Refseq': [('RefSeq', 100)],
#  'Resfinder': [('ResFinder', 100)],
#  'S-Plus': [('S-PLUS', 100)],
#  'SPSS Amos': [('SPSS AMOS', 100)],
#  'SatScan': [('SaTScan', 100)],
#  'Scala': [('SCALA', 100)],
#  'Search': [('SEARCH', 100)],
#  'Sedfit': [('SEDFIT', 100)],
#  'Seqman': [('SeqMan', 100)],
#  'Sequest': [('SEQUEST', 100)],
#  'SiScan': [('SISCAN', 100)],
#  'Sift': [('SIFT', 100)],
#  'Simca-P': [('SIMCA-P', 100)],
#  'Simplot': [('SimPlot', 100)],
#  'Sirius': [('SIRIUS', 100)],
#  'Skyscan': [('SkyScan', 100)],
#  'Softworx': [('SoftWoRx', 100)],
#  'Stata/IC': [('STATA/IC', 100)],
#  'Stata/MP': [('STATA/MP', 100)],
#  'Stata/SE': [('STATA/SE', 100)],
#  'Structure': [('STRUCTURE', 100)],
#  'Sybyl': [('SYBYL', 100)],
#  'Sybyl-X': [('SYBYL-X', 100)],
#  'TRaCE': [('TRACE', 100)],
#  'Tandem': [('TANDEM', 100)],
#  'Tassel': [('TASSEL', 100)],
#  'TomTom': [('TOMTOM', 100)],
#  'Tomtec': [('TomTec', 100)],
#  'Tomtom': [('TOMTOM', 100)],
#  'Topas': [('TOPAS', 100)],
#  'Tracer': [('TRACER', 100)],
#  'Tree-Puzzle': [('TREE-PUZZLE', 100)],
#  'TreeMix': [('TREEMIX', 100)],
#  'Treefinder': [('TreeFinder', 100)],
#  'Turbomole': [('TURBOMOLE', 100)],
#  'Uclust': [('UCLUST', 100)],
#  'Unet': [('UNet', 100)],
#  'Usearch': [('USEARCH', 100)],
#  'Venny': [('VENNY', 100)],
#  'Verify3D': [('VERIFY3D', 100)],
#  'Vicon': [('VICON', 100)],
#  'WinPepi': [('WINPEPI', 100)],
#  'Winsteps': [('WINSTEPS', 100)],
#  'Xcalibur': [('XCalibur', 100)],
#  'Xplor-NIH': [('XPLOR-NIH', 100)],
#  'Zemax': [('ZEMAX', 100)],
#  'Zen': [('ZEN', 100)],
#  'adonis': [('ADONIS', 100)],
#  'ape': [('APE', 100)],
#  'bcftools': [('BCFtools', 100)],
#  'bismark': [('Bismark', 100)],
#  'bwa mem': [('BWA MEM', 100)],
#  'bwa-mem': [('BWA MEM', 100)],
#  'car': [('CAR', 100)],
#  'caret': [('Caret', 100)],
#  'cd-hit-est': [('CD-HIT-EST', 100)],
#  'cpptraj': [('CPPTRAJ', 100)],
#  'eXpress': [('Express', 100)],
#  'fastStructure': [('fastSTRUCTURE', 100)],
#  'fastx': [('FASTX', 100)],
#  'gamlss': [('GAMLSS', 100)],
#  'gcc': [('GCC', 100)],
#  'gcrma': [('GCRMA', 100)],
#  'glm': [('GLM', 100)],
#  'glmnet': [('Glmnet', 100)],
#  'heatmap': [('HeatMap', 100)],
#  'hmmsearch': [('HMMsearch', 100)],
#  'inForm': [('InForm', 100)],
#  'jModelTest': [('JMODELTEST', 100)],
#  'keras': [('Keras', 100)],
#  'lavaan': [('Lavaan', 100)],
#  'mFold': [('MFOLD', 100)],
#  'maps': [('MAPS', 100)],
#  'mclust': [('MCLUST', 100)],
#  'mega': [('MEGA', 100)],
#  'mfold': [('MFOLD', 100)],
#  'mice': [('MICE', 100)],
#  'msconvert': [('MSConvert', 100)],
#  'mySQL': [('MySQL', 100)],
#  'nucmer': [('NUCmer', 100)],
#  'pLink': [('PLINK', 100)],
#  'perl': [('PERL', 100)],
#  'phrap': [('Phrap', 100)],
#  'pls': [('PLS', 100)],
#  'psi-blast': [('PSI-BLAST', 100)],
#  'pythia': [('Pythia', 100)],
#  'rstan': [('RStan', 100)],
#  'sPLS': [('SPLS', 100)],
#  'samtools mpileup': [('SAMtools mpileup', 100)],
#  'scanpy': [('Scanpy', 100)],
#  'shiny': [('Shiny', 100)],
#  'smartpca': [('SMARTPCA', 100)],
#  'tBLASTx': [('TBLASTX', 100)],
#  'tBlastn': [('TBLASTN', 100)],
#  'tblastx': [('TBLASTX', 100)],
#  'uclust': [('UCLUST', 100)],
#  'viewer': [('Viewer', 100)],
#  'vsearch': [('VSEARCH', 100)]}

# %%
# Converting this to a dictionary
df_mapping = pd.DataFrame.from_dict(s2s, orient='index').reset_index()\
                .rename(columns={'index':'sft1', 0: 'sft2'})

# Specify the CSV file path
csv_file_path = '../../data/czi_mentions_old_disambiguation_mapping.csv'

# Save the DataFrame as a CSV file
df_mapping.to_csv(csv_file_path, index=False)
